# %%
import pandas as pd

acc_random = pd.read_csv('/home/user/Desktop/bsh/PT4AL/acc/main_best_acc_wood_random.txt', sep=' ',  names=['random', 'first', 'acc', 'value'])
acc_pt4al = pd.read_csv('/home/user/Desktop/bsh/PT4AL/acc/main_best_acc_wood_pt4al.txt', sep=' ', header=None, names=['iteration', 'acc']) 
acc_cutpaste = pd.read_csv('/home/user/Desktop/bsh/PT4AL/acc/main_best_acc_wood_cutpaste.txt', sep=' ', header=None, names=['iteration', 'acc']) 
auroc_random = pd.read_csv('/home/user/Desktop/bsh/PT4AL/auroc/main_best_auroc_wood_random.txt', sep=' ', names=['random', 'first', 'auroc', 'value'])
auroc_pt4al = pd.read_csv('/home/user/Desktop/bsh/PT4AL/auroc/main_best_auroc_wood_pt4al.txt', sep=' ', header=None, names=['iteration', 'auroc'])
auroc_cutpaste = pd.read_csv('/home/user/Desktop/bsh/PT4AL/auroc/main_best_auroc_wood_cutpaste.txt', sep=' ', header=None, names=['iteration', 'auroc'])

display(acc_random)
display(acc_pt4al)
display(acc_cutpaste)
display(auroc_random)
display(auroc_pt4al)
display(auroc_cutpaste)
# Out:
#    random  first  acc      value
# 0  random  first  acc  85.294118
#    iteration        acc
# 0          0  88.235294
# 1          1  88.235294
# 2          2  89.705882
# 3          3  88.235294
# 4          4  88.235294
#    iteration        acc
# 0          0  89.705882
# 1          1  88.235294
# 2          2  89.705882
# 3          3  91.176471
# 4          4  92.647059
#    random  first  auroc     value
# 0  random  first  auroc  0.781184
#    iteration     auroc
# 0          0  0.744128
# 1          1  0.944078
# 2          2  0.941030
# 3          3  0.958411
# 4          4  0.947604
#    iteration     auroc
# 0          0  0.924854
# 1          1  0.910205
# 2          2  0.955215
# 3          3  0.969179
# 4          4  0.984612

# %%
import matplotlib.pyplot as plt

plt.plot(auroc_pt4al['iteration'], auroc_pt4al['auroc'],label='rotation')
plt.plot(auroc_cutpaste['iteration'], auroc_cutpaste['auroc'],label='cutpaste')

plt.scatter(auroc_pt4al.loc[0, 'iteration'], auroc_random.loc[0, 'value'], color='red',label='random') # 첫 번째 x축 값에 해당하는 위치에 점을 찍습니다.

# plt.axhline(y=0.9945, color='r', linestyle='--', label='ideal model_auroc')     # bottle
# plt.axhline(y=0.9428, color='r', linestyle='--', label='ideal model_auroc')     # carpet
# plt.axhline(y=0.9916, color='r', linestyle='--', label='ideal model_auroc')     # cable
# plt.axhline(y=0.9772, color='r', linestyle='--', label='ideal model_auroc')     # "capsule"
# plt.axhline(y=0.9929, color='r', linestyle='--', label='ideal model_auroc')     # "hazelnut"
# plt.axhline(y=0.9811, color='r', linestyle='--', label='ideal model_auroc')     # "metal_nut"
# plt.axhline(y=0.8565, color='r', linestyle='--', label='ideal model_auroc')     # "pill" 
# plt.axhline(y=0.7644, color='r', linestyle='--', label='ideal model_auroc')     # "screw"
# plt.axhline(y=0.95, color='r', linestyle='--', label='ideal model_auroc')       # "toothbrush"
# plt.axhline(y=0.9740, color='r', linestyle='--', label='ideal model_auroc')     # "transistor"
# plt.axhline(y=0.9561, color='r', linestyle='--', label='ideal model_auroc')     # "zipper"
# plt.axhline(y=0.9428, color='r', linestyle='--', label='ideal model_auroc')     # "carpet"
# plt.axhline(y=0.7080, color='r', linestyle='--', label='ideal model_auroc')     # "grid"
# plt.axhline(y=0.9705, color='r', linestyle='--', label='ideal model_auroc')     # "leather"
# plt.axhline(y=0.9975, color='r', linestyle='--', label='ideal model_auroc')     # "tile"
plt.axhline(y=0.9874, color='r', linestyle='--', label='ideal model_auroc') # "wood"

plt.title('AUC-ROC Value')
plt.xlabel('iteration')
plt.ylabel('auroc')
plt.legend(loc='lower right')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(acc_pt4al['iteration'], acc_pt4al['acc'],label='rotation')
plt.plot(acc_cutpaste['iteration'], acc_cutpaste['acc'],label='cutpaste')

plt.scatter(acc_pt4al.loc[0, 'iteration'], acc_random.loc[0, 'value'], color='red',label='random') # 첫 번째 x축 값에 해당하는 위치에 점을 찍습니다.

# plt.axhline(y=93.33, color='r', linestyle='--', label='ideal model_acc')     # bottle
# plt.axhline(y=91.03, color='r', linestyle='--', label='ideal model_acc')     # cable
# plt.axhline(y=87.67, color='r', linestyle='--', label='ideal model_acc')     # "capsule"
# plt.axhline(y=82.93, color='r', linestyle='--', label='ideal model_acc')     # carpet
# plt.axhline(y=93.20, color='r', linestyle='--', label='ideal model_acc')     # "hazelnut"
# plt.axhline(y=91.30, color='r', linestyle='--', label='ideal model_acc')     # "metal_nut"
# plt.axhline(y=70.00, color='r', linestyle='--', label='ideal model_acc')     # "pill"
# plt.axhline(y=74.49, color='r', linestyle='--', label='ideal model_acc')     # "screw"
# plt.axhline(y=91.66, color='r', linestyle='--', label='ideal model_acc')     # "toothbrush"
# plt.axhline(y=95.24, color='r', linestyle='--', label='ideal model_acc')     # "transistor"
# plt.axhline(y=83.13, color='r', linestyle='--', label='ideal model_acc')     # "zipper"
# plt.axhline(y=73.61, color='r', linestyle='--', label='ideal model_acc')     # "grid"
# plt.axhline(y=89.47, color='r', linestyle='--', label='ideal model_acc')     # "leather"
# plt.axhline(y=91.67, color='r', linestyle='--', label='ideal model_acc')     # "tile"
plt.axhline(y=92.65, color='r', linestyle='--', label='ideal model_acc') # "wood"

plt.title('Accuracy Value')
plt.xlabel('iteration')
plt.ylabel('acc')
plt.legend(loc='lower right')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
